# %% [markdown]
# # 0. Introduction
# This project trains a Long Short Term Memory (LSTM) network to detect and classify a text written in English according to a particular variant: whether it is British or American.

# %% [markdown]
# ## 0.1 Preliminary Libraries and Packages

# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd
import math
from nltk.corpus import brown
import numpy as np

# %% [markdown]
# # 1. Preprocess

# %% [markdown]
# ## 1.1 Brown Corpus

# %%
nltk.download('brown')
brown.words()[:10]
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of']

# %%
print(len(brown.words()))
# Out:
# 1161192

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
import string

# Added extra punctuation
punctuation = ['!','"','#','$','%','&',"'",'(',')','*','+',',','-','.','/',
               ':',';','<','=','>','?','@','[','\\',']','^','_','`','{','|','}','~','``',"''",'--']

lower_brown = [x.lower() for x in brown.words()]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(lower_brown[:10])
print(len(lower_brown))
# Out:
# ['the', 'fulton', 'county', 'grand', 'jury', 'said', 'friday', 'an', 'investigation', 'of']
# 1161192

# %%
pun_stop = punctuation + stopwords.words('english')
filter_brown = [x for x in lower_brown if x not in pun_stop]

# %%
print(filter_brown[:10])
# Out:
# ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', "atlanta's", 'recent', 'primary']

# %%
filter_brown2 = list(filter(lambda x: x.isalpha() and len(x) > 1, filter_brown))
# remove numbers and single letter words

# %%
print(filter_brown2[:10])
# Out:
# ['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'recent', 'primary', 'election']

# %%
print(len(filter_brown2))
# Out:
# 508631

# %% [markdown]
# ## 1.2 LOB Corpus

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/LOB"
# Out:
# lob.txt

# %%
f = open('/content/drive/My Drive/LOB/lob.txt')
lob = f.readlines()

# %%
print(lob[:100])
# Out:
# ['<1 TEXT A1>\n', "'STOP ELECTING LIFE PEERS'\n", 'By TREVOR WILLIAMS\n', '   A MOVE to stop Mr. Gaitskell from nominating any more Labour\n', 'life Peers is to be made at a meeting of Labour M Ps tomorrow.\n', '   Mr. Michael Foot has put down a resolution on the subject and\n', 'he is to be backed by Mr. Will Griffiths, M P for Manchester\n', 'Exchange.\n', '   Though they may gather some Left-wing support, a large majority\n', 'of Labour M Ps are likely to turn down the Foot-Griffiths\n', 'resolution.\n', "'ABOLISH LORDS'\n", "   Mr. Foot's line will be that as Labour M Ps opposed the\n", 'Government Bill which brought life peers into existence, they should\n', 'not now put forward nominees.\n', '   He believes that the House of Lords should be abolished and that\n', 'Labour should not take any steps which would appear to "prop up" an\n', 'out-dated institution.\n', '   Since 1958, 13 Labour life Peers and Peeresses have been created.\n', '   Most Labour sentiment would still favour the abolition of the\n', 'House of Lords, but while it remains Labour has to have an adequate\n', 'number of members.\n', 'AFRICANS DROP RIVALRY TO FIGHT SIR ROY\n', 'By DENNIS NEWSON\n', '   THE two rival African Nationalist Parties of Northern Rhodesia\n', 'have agreed to get together to face the challenge from Sir Roy\n', 'Welensky, the Federal Premier.\n', "   Delegates from Mr. Kenneth Kaunda's United National\n", "Independence Party (28, members) and Mr. Harry Nkumbula's\n", 'African National Congress (4,) will meet in London today to\n', 'discuss a common course of action.\n', '   Sir Roy is violently opposed to Africans getting an elected\n', 'majority in Northern Rhodesia, but the Colonial Secretary, Mr. Iain\n', 'Macleod, is insisting on a policy of change.\n', "   Sir Roy's United Federal Party is boycotting the London talks on\n", "the Protectorate's future.\n", '   Said Mr. Nkumbula last night: "We want to discuss what to do\n', 'if the British Government gives in to Sir Roy and the talks fall\n', 'through. There are bound to be demonstrations."\n', 'All revealed\n', "   Yesterday Sir Roy's chief aide, Mr. Julius Greenfield,\n", 'telephoned his chief a report on his talks with Mr. Macmillan at\n', 'Chequers.\n', '   Mr. Macleod went on with the conference at Lancaster House\n', 'despite the crisis which had blown up. He has now revealed his full\n', 'plans to the Africans and Liberals attending.\n', '   These plans do not give the Africans the overall majority they\n', 'are seeking. African delegates are studying them today.\n', '   The conference will meet to discuss the function of a proposed\n', 'House of Chiefs.\n', 'No secret talks- Macleod\n', 'By HUGH PILCHER\n', '   MR. IAIN MACLEOD, the Colonial Secretary, denied in the\n', 'Commons last night that there have been secret negotiations on\n', "Northern Rhodesia's future.\n", '   The Northern Rhodesia conference in London has been boycotted\n', "by the two main settlers' parties- the United Federal Party and the\n", 'Dominion Party.\n', '   But representatives of Sir Roy Welensky, Prime Minister of the\n', 'Central African Federation, went to Chequers at the week-end for talks\n', 'with Mr. Macmillan. Northern Rhodesia is a member of the\n', 'Federation.\n', '   Mr. Macleod was not at the week-end meeting. But he told M\n', 'Ps yesterday: "I have no knowledge of secret negotiations."\n', '   He said Britain had an obligation to consult the Federal\n', 'Government. But the final decision remained with the British\n', 'Government.\n', "   Mr. James Callaghan, Labour's Colonial spokesman, said Sir\n", 'Roy had no right to delay progress in the talks by refusing to sit\n', 'round the conference table.\n', '   Mr. Macleod thought the two Rhodesian parties had refused to\n', 'attend the talks because Sir Roy had found messages sent from the\n', 'Government were "unsatisfactory."\n', '   African delegates to the talks yesterday called on Mr.\n', "Macmillan to cease his negotiations w ...

# %%
lob2 = lob.copy()

# %%
lob2 = [''.join(lob2)]

# %%
lob3 = str(lob2[0])

# %%
lob3 = lob3.replace("<","")
lob3 = lob3.replace(">","")
lob3 = lob3.replace("\n"," ")

# %%
def string_to_list(string):
    new_list = list(string.split(" "))
    return new_list

# %%
lob4 = string_to_list(lob3)

# %%
lob4[:10]
# Out:
# ['1',
#  'TEXT',
#  'A1',
#  "'STOP",
#  'ELECTING',
#  'LIFE',
#  "PEERS'",
#  'By',
#  'TREVOR',
#  'WILLIAMS']

# %%
lower_lob = [x.lower() for x in lob4]

# %%
print(lower_lob[:10])
print(len(lower_lob))
# Out:
# ['1', 'text', 'a1', "'stop", 'electing', 'life', "peers'", 'by', 'trevor', 'williams']
# 1068614

# %%
filter_lob = [x for x in lower_lob if x not in pun_stop]

# %%
print(filter_lob[:10])
# Out:
# ['1', 'text', 'a1', "'stop", 'electing', 'life', "peers'", 'trevor', 'williams', '']

# %%
filter_lob2 = list(filter(lambda x: x.isalpha() and len(x) > 1, filter_lob))
# remove numbers and single letter words

# %%
print(filter_lob2[:10])
# Out:
# ['text', 'electing', 'life', 'trevor', 'williams', 'move', 'stop', 'gaitskell', 'nominating', 'labour']

# %%
print(len(filter_lob2))
# Out:
# 389754

# %% [markdown]
# ## 1.3 Converting the Corpora to a Dataframe

# %%
def create_substrings(x): # x is a list of words
  listoflists = []
  n = 0
  m = 10
  for i in range(int(len(x)/10)):
    listx = []
    for j in range(n,m):
      listx.append(x[j])
    listoflists.append(listx)
    n += 10
    m += 10
  return listoflists

# %%
lob_list = create_substrings(filter_lob2)
brown_list = create_substrings(filter_brown2)

# %%
len(lob_list)
# Out:
# 38975

# %%
len(brown_list)
# Out:
# 50863

# %%
print(brown_list[0:5])
# Out:
# [['fulton', 'county', 'grand', 'jury', 'said', 'friday', 'investigation', 'recent', 'primary', 'election'], ['produced', 'evidence', 'irregularities', 'took', 'place', 'jury', 'said', 'presentments', 'city', 'executive'], ['committee', 'charge', 'election', 'deserves', 'praise', 'thanks', 'city', 'atlanta', 'manner', 'election'], ['conducted', 'term', 'jury', 'charged', 'fulton', 'superior', 'court', 'judge', 'durwood', 'pye'], ['investigate', 'reports', 'possible', 'irregularities', 'primary', 'ivan', 'allen', 'relative', 'handful', 'reports']]

# %%
print(lob_list[0:5])
# Out:
# [['text', 'electing', 'life', 'trevor', 'williams', 'move', 'stop', 'gaitskell', 'nominating', 'labour'], ['life', 'peers', 'made', 'meeting', 'labour', 'ps', 'michael', 'foot', 'put', 'resolution'], ['subject', 'backed', 'manchester', 'though', 'may', 'gather', 'large', 'majority', 'labour', 'ps'], ['likely', 'turn', 'line', 'labour', 'ps', 'opposed', 'government', 'bill', 'brought', 'life'], ['peers', 'put', 'forward', 'believes', 'house', 'lords', 'abolished', 'labour', 'take', 'steps']]

# %%
brown_list[0]
# Out:
# ['fulton',
#  'county',
#  'grand',
#  'jury',
#  'said',
#  'friday',
#  'investigation',
#  'recent',
#  'primary',
#  'election']

# %%
df_lob = pd.DataFrame()

# %%
df_lob['text'] = lob_list

# %%
df_lob['isBrown'] = 0

# %%
df_lob
# Out:
#                                                     text  isBrown
# 0      [text, electing, life, trevor, williams, move,...        0
# 1      [life, peers, made, meeting, labour, ps, micha...        0
# 2      [subject, backed, manchester, though, may, gat...        0
# 3      [likely, turn, line, labour, ps, opposed, gove...        0
# 4      [peers, put, forward, believes, house, lords, ...        0
# ...                                                  ...      ...
# 38970  [peering, thought, prudent, let, go, stopped, ...        0
# 38971  [prevent, left, would, make, bid, freedom, wri...        0
# 38972  [left, hands, free, easily, clasping, throat, ...        0
# 38973  [turned, towards, room, manoeuvre, moving, not...        0
# 38974  [hand, stomach, got, round, started, hissing, ...        0
#
# [38975 rows x 2 columns]

# %%
df_brown = pd.DataFrame()

# %%
df_brown['text'] = brown_list

# %%
df_brown['isBrown'] = 1

# %%
df_brown
# Out:
#                                                     text  isBrown
# 0      [fulton, county, grand, jury, said, friday, in...        1
# 1      [produced, evidence, irregularities, took, pla...        1
# 2      [committee, charge, election, deserves, praise...        1
# 3      [conducted, term, jury, charged, fulton, super...        1
# 4      [investigate, reports, possible, irregularitie...        1
# ...                                                  ...      ...
# 50858  [headache, count, compassionately, perelman, r...        1
# 50859  [dropped, seat, exhaling, looked, across, aisl...        1
# 50860  [song, living, doll, mistake, bang, wide, chee...        1
# 50861  [midwestern, lineage, mouth, whose, fault, car...        1
# 50862  [voluptuous, able, gauge, swift, greedy, glanc...        1
#
# [50863 rows x 2 columns]

# %%
df = pd.concat([df_lob, df_brown]).reset_index(drop = True)
df
# Out:
#                                                     text  isBrown
# 0      [text, electing, life, trevor, williams, move,...        0
# 1      [life, peers, made, meeting, labour, ps, micha...        0
# 2      [subject, backed, manchester, though, may, gat...        0
# 3      [likely, turn, line, labour, ps, opposed, gove...        0
# 4      [peers, put, forward, believes, house, lords, ...        0
# ...                                                  ...      ...
# 89833  [headache, count, compassionately, perelman, r...        1
# 89834  [dropped, seat, exhaling, looked, across, aisl...        1
# 89835  [song, living, doll, mistake, bang, wide, chee...        1
# 89836  [midwestern, lineage, mouth, whose, fault, car...        1
# 89837  [voluptuous, able, gauge, swift, greedy, glanc...        1
#
# [89838 rows x 2 columns]

# %%
# Obtain the total words in the dataset
list_of_words = []
for i in df.text:
    for j in i:
        list_of_words.append(j)

# %%
len(list_of_words)
# Out:
# 898380

# %%
# Obtain the total number of unique words
total_words = len(list(set(list_of_words))) #set, only unique ones
total_words
# Out:
# 51140

# %%
# join the words into a string
df['text_joined'] = df['text'].apply(lambda x: " ".join(x))

# %%
df
# Out:
#                                                     text  isBrown  \
# 0      [text, electing, life, trevor, williams, move,...        0
# 1      [life, peers, made, meeting, labour, ps, micha...        0
# 2      [subject, backed, manchester, though, may, gat...        0
# 3      [likely, turn, line, labour, ps, opposed, gove...        0
# 4      [peers, put, forward, believes, house, lords, ...        0
# ...                                                  ...      ...
# 89833  [headache, count, compassionately, perelman, r...        1
# 89834  [dropped, seat, exhaling, looked, across, aisl...        1
# 89835  [song, living, doll, mistake, bang, wide, chee...        1
# 89836  [midwestern, lineage, mouth, whose, fault, car...        1
# 89837  [voluptuous, able, gauge, swift, greedy, glanc...        1
#
#                                              text_joined
# 0      text electing life trevor williams move stop g...
# 1      life peers made meeting labour ps michael foot...
# 2      subject backed manchester though may gather la...
# 3      likely turn line labour ps opposed government ...
# 4      peers put forward believes house lords abolish...
# ...                                                  ...
# 89833  headache count compassionately perelman revuls...
# 89834  dropped seat exhaling looked across aisle whol...
# 89835  song living doll mistake bang wide cheekbones ...
# 89836  midwestern lineage mouth whose fault carping p...
# 89837  voluptuous able gauge swift greedy glance figu...
#
# [89838 rows x 3 columns]

# %% [markdown]
# ## 1.4 Visualize the Cleaned Up Dataset

# %%
data = df.to_csv('corpora.csv')

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# plot the word cloud for the Brown Corpus
plt.figure(figsize = (10,10))
wc = WordCloud(max_words = 2000 , width = 1600,
               height = 800).generate(" ".join(df[df.isBrown == 1].text_joined))
plt.imshow(wc, interpolation = 'bilinear')

# %%
# plot the word cloud for the LOB Corpus
plt.figure(figsize = (10,10))
wc = WordCloud(max_words = 2000 , width = 1600,
               height = 800).generate(" ".join(df[df.isBrown == 0].text_joined))
plt.imshow(wc, interpolation = 'bilinear')

# %% [markdown]
# # 2. The Model

# %% [markdown]
# ## 2.1 Tokenization and Padding

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
# length of maximum document will be needed to create word embeddings
maxlen = -1
for doc in df.text_joined:
    tokens = nltk.word_tokenize(doc)
    if(maxlen<len(tokens)):
        maxlen = len(tokens)
print("The maximum number of words in any document is =", maxlen)
# Out:
# The maximum number of words in any document is = 12

# %%
# split data into test and train
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.text_joined, df.isBrown, test_size = 0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Bidirectional

# %%
# Create a tokenizer to create sequences of tokenized words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(x_train)
train_sequences = tokenizer.texts_to_sequences(x_train)
test_sequences = tokenizer.texts_to_sequences(x_test)

# %%
# Example of tokenized text
print("The encoding for document\n",df.text_joined[100],"\n is : ",train_sequences[100])
# Out:
# The encoding for document
#  represented sir roderick taken part detailed common market exchanges past
#  is :  [21, 704, 4622, 234, 345, 235, 602, 4261, 443, 361]

# %%
padded_train = pad_sequences(train_sequences,maxlen = 12, padding = 'post', truncating = 'post')
padded_test = pad_sequences(test_sequences,maxlen = 12, truncating = 'post')

# %%
for i,doc in enumerate(padded_train[:3]):
     print("The padded encoding for document",i+1," is : ",doc)
# Out:
# The padded encoding for document 1  is :  [ 291  539  955  680 1849  368 1648 2328 3153 3503    0    0]
# The padded encoding for document 2  is :  [4147  113 2029   24  161   51   11 3211  524   43    0    0]
# The padded encoding for document 3  is :  [1727  300 1009   76  400  198  624  300 3282 2744    0    0]

# %% [markdown]
# ## 2.2 Building and Training the Model

# %%
# Sequential Model
model = Sequential()

# embeddidng layer
model.add(Embedding(total_words, output_dim = 128))

# Bi-Directional RNN and LSTM
model.add(Bidirectional(LSTM(128)))

# Dense layers
model.add(Dense(128, activation = 'relu'))
model.add(Dense(1,activation= 'sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         6545920
#
#  bidirectional (Bidirectiona  (None, 256)              263168
#  l)
#
#  dense (Dense)               (None, 128)               32896
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,842,113
# Trainable params: 6,842,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
total_words
# Out:
# 51140

# %%
y_train = np.asarray(y_train)

# %%
# train the model, substrings = 10
model.fit(padded_train, y_train, batch_size = 64, validation_split = 0.1, epochs = 1)
# Out:
# 1011/1011 [==============================] - 189s 182ms/step - loss: 0.5409 - acc: 0.7155 - val_loss: 0.4841 - val_acc: 0.7619

# %% [markdown]
# # 3. Assessing the Model Performance

# %%
# make prediction
pred = model.predict(padded_test)
# Out:
# 562/562 [==============================] - 11s 18ms/step

# %%
# if the predicted value is >0.5 it is American (Brown),
# else it is British (LOB)

prediction = []
for i in range(len(pred)):
    if pred[i].item() > 0.5:
        prediction.append(1)
    else:
        prediction.append(0)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(list(y_test), prediction)

print("Model Accuracy : ", accuracy)
# Out:
# Model Accuracy :  0.7621326803205699

# %%
import seaborn as sns

# %%
# get the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(list(y_test), prediction)
plt.figure(figsize = (8, 8))
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
# category dict
category = { 0: 'British', 1 : "American"}

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
f1 = f1_score(y_test, prediction)

print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)
# Out:
# Precision: 0.7651114892092773
# Recall: 0.83805787150564
# F1 score: 0.799925100646007
